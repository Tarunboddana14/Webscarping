# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bi_analysis = pd.read_csv("analysis_data.csv")

# %%
bi_analysis
# Out:
#          Apartment Type  Area In sqft        Facing  No_of_bathrooms  \
# 0       1 BHK Apartment           650   East facing                1
# 1       2 BHK Apartment          1160  North facing                2
# 2     1 BHK Independent           600   East facing                1
# 3       3 BHK Apartment          1575   West facing                3
# 4     2 BHK Independent           900       Unknown                2
# ...                 ...           ...           ...              ...
# 2935  2 BHK Independent          1000       Unknown                2
# 2936  1 BHK Independent           350       Unknown                1
# 2937    3 BHK Apartment          1500       Unknown                3
# 2938  1 BHK Independent           600       Unknown                1
# 2939  1 BHK Independent           500       Unknown                1
#
#            Status    Price              Area       City
# 0       Furnished  15000.0        Gachibowli  Hyderabad
# ...

# %%
bi_analysis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2940 entries, 0 to 2939
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Apartment Type   2940 non-null   object
#  1   Area In sqft     2940 non-null   int64
#  2   Facing           2940 non-null   object
#  3   No_of_bathrooms  2940 non-null   int64
#  4   Status           2940 non-null   object
#  5   Price            2940 non-null   float64
#  6   Area             2940 non-null   object
#  7   City             2940 non-null   object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 183.9+ KB

# %% [markdown]
# # Scatter Plot
# ## Numeric vs Numeric
# ### Scatter plot for No_of_bathrooms vs Price

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=bi_analysis["No_of_bathrooms"],y=bi_analysis["Price"],alpha=0.1,color = "#ff0000")
plt.xlabel("Area In sqft")
plt.ylabel("Price")
plt.show()

# %%
plt.figure(figsize=(5,5),dpi=150)
sns.scatterplot(x=bi_analysis["Price"],y=bi_analysis["Area In sqft"],alpha=0.05,marker="*",color = "#C11C84")
# Out:
# <Axes: xlabel='Price', ylabel='Area In sqft'>

# %%
sns.pairplot(bi_analysis)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Numeric VS Category or Category VS Numeric
# ### Bar graph for Facing vs Price

# %%
plt.figure(figsize=(20,10))
plt.bar(x=bi_analysis["Facing"],height=bi_analysis["Price"],color='blue',edgecolor='red') # bar is vertical, barh gives horizontal bar
plt.title("Prices based on Facing")
plt.xlabel('Facing')
plt.ylabel('Price')
plt.xticks(rotation=90)
plt.show()

# %%
x_axis = bi_analysis["Facing"].unique() 
x_axis
# Out:
# array(['East facing', 'North facing', 'West facing', 'Unknown',
#        'NorthEast facing', 'NorthWest facing', 'SouthEast facing',
#        'SouthWest facing', 'South facing'], dtype=object)

# %%
y_axis = bi_analysis["Price"].unique()
y_axis
# Out:
# array([1.5000e+04, 1.6000e+04, 8.0000e+03, 3.0000e+04, 1.4000e+04,
#        1.0000e+04, 2.2000e+04, 4.8000e+04, 2.8000e+04, 1.8000e+04,
#        1.7000e+04, 2.5000e+07, 7.5000e+04, 6.5000e+03, 4.0000e+04,
#        1.1000e+04, 2.0000e+04, 6.2000e+04, 3.1000e+04, 7.0000e+03,
#        1.2000e+04, 6.0000e+04, 4.2000e+04, 2.3000e+04, 1.0500e+04,
#        6.5000e+04, 1.3000e+04, 3.4000e+04, 1.9000e+04, 1.2500e+07,
#        2.4000e+04, 3.0000e+03, 4.5000e+04, 3.5000e+04, 3.8000e+04,
#        5.0000e+04, 4.5000e+03, 5.8000e+04, 5.4000e+04, 8.5000e+03,
#        3.2000e+04, 1.2001e+04, 2.1000e+04, 9.0000e+03, 5.5000e+03,
#        6.0000e+03, 7.0000e+04, 6.2000e+03, 5.0000e+03, 9.5000e+03,
#        9.5000e+04, 1.5500e+04, 1.8500e+04, 1.7500e+04, 7.5000e+03,
#        1.4500e+04, 1.3500e+04, 5.1000e+04, 9.0000e+04, 6.4000e+03,
#        4.0000e+03, 5.5000e+04, 2.5000e+06, 8.8000e+04, 2.1500e+04,
#        3.9000e+04, 3.6000e+04, 2.7500e+04, 1.9500e+04, 2.7000e+04,
# ...

# %%
plt.figure(figsize=(10,6))
plt.bar(x=bi_analysis["City"],height=bi_analysis["Area In sqft"],color='#f6b092',edgecolor='red') # bar is vertical, barh gives horizontal bar
plt.title("City VS Area in sqft)")
plt.xlabel('City')
plt.ylabel('Area in sqft')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.bar(x=bi_analysis["City"],height=bi_analysis["Price"],color='blue',edgecolor='red') # bar is vertical, barh gives horizontal bar
plt.title("Price vs City")
plt.xlabel('City')
plt.ylabel('Price')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.bar(x=bi_analysis["No_of_bathrooms"],height=bi_analysis["Price"],color='blue',edgecolor='red') # bar is vertical, barh gives horizontal bar
plt.title("No_of_bathrooms vs Price")
plt.xlabel('No_of_bathrooms')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# # Line Plot
# ### Categorical vs Numerical
# #### Lineplot for Facing vs Price

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=bi_analysis, x="Facing", y="Price")
plt.xticks(rotation = 90)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=bi_analysis, x="City", y="Price")
plt.xticks(rotation = 90)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Violinplot

# %%
sns.violinplot(data=bi_analysis,x="City",y="Price")
plt.xticks(rotation = 90)
plt.show()

# %%
sns.violinplot(data=bi_analysis,x="City", y ="Area In sqft")
plt.xticks(rotation = 90)
plt.show()

# %%
sns.violinplot(data=bi_analysis,x="Apartment Type", y ="Price")
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.heatmap(bi_analysis.corr(),annot=True,cmap='coolwarm',vmin=-1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 2
#       1 plt.figure(figsize=(12,10))
# ----> 2 sns.heatmap(bi_analysis.corr(),annot=True,cmap='coolwarm',vmin=-1)
#       3 plt.show()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...
