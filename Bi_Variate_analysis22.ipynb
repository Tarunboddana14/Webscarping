# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bi_analysis = pd.read_csv("analysis_data2.csv")

# %%
bi_analysis
# Out:
#          Apartment Type  Area In sqft        Facing  No_of_bathrooms  \
# 0       1 BHK Apartment           650   East facing                1
# 1       2 BHK Apartment          1160  North facing                2
# 2     1 BHK Independent           600   East facing                1
# 3       3 BHK Apartment          1575   West facing                3
# 4     2 BHK Independent           900       Unknown                2
# ...                 ...           ...           ...              ...
# 1931  2 BHK Independent          1000       Unknown                2
# 1932  1 BHK Independent           350       Unknown                1
# 1933    3 BHK Apartment          1500       Unknown                3
# 1934  1 BHK Independent           600       Unknown                1
# 1935  1 BHK Independent           500       Unknown                1
#
#            Status    Price              Area       City
# 0       Furnished  15000.0        Gachibowli  Hyderabad
# ...

# %%
bi_analysis.duplicated().sum()
# Out:
# 0

# %%
bi_analysis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1936 entries, 0 to 1935
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Apartment Type   1936 non-null   object
#  1   Area In sqft     1936 non-null   int64
#  2   Facing           1936 non-null   object
#  3   No_of_bathrooms  1936 non-null   int64
#  4   Status           1936 non-null   object
#  5   Price            1936 non-null   float64
#  6   Area             1936 non-null   object
#  7   City             1936 non-null   object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 121.1+ KB

# %% [markdown]
# # Scatter Plot
# ## Numeric vs Numeric
# ### Scatter plot for Area In sqft vs Price

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=bi_analysis["Area In sqft"],y=bi_analysis["Price"],alpha=0.1,color = "#C11C84")
plt.xlabel("Area In sqft")
plt.ylabel("Price")
plt.show()

# %%
plt.figure(figsize=(5,5),dpi=150)
sns.scatterplot(x=bi_analysis["No_of_bathrooms"],y=bi_analysis["Area In sqft"],alpha=0.05,marker="*",color="black")
plt.xticks(rotation=90)
plt.show()

# %%
sns.pairplot(bi_analysis)

# %% [markdown]
# ## Numeric VS Category or Category VS Numeric
# ### Bar graph for Price vs Area

# %%
plt.figure(figsize=(5,5))
plt.bar(x=bi_analysis["City"],height=bi_analysis["Price"],color='blue',edgecolor='red') # bar is vertical, barh gives horizontal bar
plt.title("Prices based on City")
plt.xlabel('Area')
plt.ylabel('Price')
plt.xticks(rotation=90)
plt.show()

# %%
x_axis = bi_analysis["Area"].unique()
x_axis

# %%
y_axis = bi_analysis["Price"].unique()
y_axis

# %%
plt.figure(figsize=(5,5))
plt.bar(x=bi_analysis["City"],height=bi_analysis["Area In sqft"],color='#f6b092',edgecolor='red') # bar is vertical, barh gives horizontal bar
plt.title("City VS Area in sqft)")
plt.xlabel('City')
plt.ylabel('Area in sqft')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.bar(x=bi_analysis["Price"],height=bi_analysis["Area"],color='blue',edgecolor='red') # bar is vertical, barh gives horizontal bar
plt.title("Price vs City")
plt.xlabel('City')
plt.ylabel('Price')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.bar(x=bi_analysis["Apartment Type"],height=bi_analysis["Price"],color='blue',edgecolor='red') # bar is vertical, barh gives horizontal bar
plt.title("Price vs BHK Type")
plt.xlabel('BHK Type')
plt.ylabel('Price')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=[20,8])
sns.pie(data=bi_analysis, x="City", y="Price")
plt.title("Price vs City")
plt.xlabel('City')
plt.xticks(rotation = 90)
plt.show()
